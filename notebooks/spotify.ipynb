# %%
import os
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv

load_dotenv()

# Spotify credentials
SPOTIFY_CLIENT_ID = os.getenv("SPOTIFY_CLIENT_ID")
SPOTIFY_CLIENT_SECRET = os.getenv("SPOTIFY_CLIENT_SECRET")
SPOTIFY_REDIRECT_URI = os.getenv("SPOTIFY_REDIRECT_URI", "http://localhost:8000/callback")

if not SPOTIFY_CLIENT_ID or not SPOTIFY_CLIENT_SECRET:
    raise ValueError("SPOTIFY_CLIENT_ID and SPOTIFY_CLIENT_SECRET environment variables must be set")

# Spotify OAuth scopes
SPOTIFY_SCOPE = "authorization_code user-read-currently-playing user-read-recently-played playlist-modify-public playlist-modify-private"

# Initialize SpotifyOAuth
sp_oauth = SpotifyOAuth(
    client_id=SPOTIFY_CLIENT_ID,
    client_secret=SPOTIFY_CLIENT_SECRET,
    redirect_uri=SPOTIFY_REDIRECT_URI,
    scope=SPOTIFY_SCOPE
)

code="AQCpaZL2CpByoj12aHuCm4KDPNI15msTVXQGc0BgPzjdRfAzUitoc1ZHx_MG07LN4dmJ7Irs9120OBUr24pATOt_IXx9_QD4e1ZJ-nZmuf_bBOtB8wY73WXcmrQomPx5KONTgD03bfgSdjHkFklgX_r-kYjgYV9DEG8bxDCzfUirkZQQAttG_NnKUjI801pjtEco2HdQRZHkVtWEfJgGYnVziW4PIBjXDFshSj6iTJlMI5c9UH0tETi9PTMWNYa6hoM3TcsYH-GOjWzwriJjUhLZH14aXrM9ax_6KLcK5-85vkhpSBdjt1FzIg"
token_info = sp_oauth.get_access_token(code, check_cache=False)
# Out:
# /var/folders/wc/n78dlsf56fn_yrr41ywnr70m0000gn/T/ipykernel_5585/960107634.py:27: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   token_info = sp_oauth.get_access_token(code, check_cache=False)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/code/personal/replay/venv/lib/python3.12/site-packages/spotipy/oauth2.py:559, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     551 response = self._session.post(
#     552     self.OAUTH_TOKEN_URL,
#     553     data=payload,
#    (...)    557     timeout=self.requests_timeout,
#     558 )
# --> 559 response.raise_for_status()
#     560 token_info = response.json()
#
# ...
